# %%
import numpy as np

# %%
a = np.array(np.random.randn(5,30))

# %%
b = np.array(np.random.randn(5,30))

# %%
a[b<=0] = 0

# %%
a
# Out:
# array([[-0.91596535,  0.        ,  0.        ,  0.        , -0.35390903,
#         -1.24190086, -0.59707341, -0.87794695,  0.        ,  0.        ,
#         -0.96235022, -0.23866431,  0.        , -1.4183854 ,  0.        ,
#          0.21473536, -0.45885683,  0.        ,  0.        , -0.58508206,
#         -0.3348169 ,  0.        ,  0.        ,  0.        ,  0.        ,
#         -0.12245143,  0.68796955, -0.44315658,  0.        ,  0.        ],
#        [ 0.        ,  0.50073764, -2.10779147,  0.        , -0.01471054,
#          0.        ,  0.        , -0.78102821,  0.        , -0.09080815,
#          0.        ,  1.74621607,  0.        ,  0.        , -0.80359678,
#          0.        ,  1.35645382,  0.        ,  0.7555731 , -0.20434299,
#          1.32289284,  0.        ,  0.53236155,  1.49764533,  1.86451607,
#          0.        , -1.81806047,  1.33009455,  2.25005436,  0.11104143],
#        [ 0.72693941, -0.51399086,  1.1055634 , -1.73852132,  0.81970568,
# ...
